# %% [markdown]
# <img src="casas.jpg" alt="casas">
#
# <h1 style = 'color:#14668a; text-align: center'>Universidad Castro Carazo</h1>
# <h3 style = 'color:#14668a; text-align: center'>Curso: Analisis de Datos</h3>
# <h3 style = 'color:#159a93; text-align: center'>Estudiante: Mariana Solis Roldan</h3>
# <h2 style = 'color:#7de0b9; text-align: center'>Proyecto Final</h2>
#
# <p style = 'text-align: justify'> El presente proyecto pretende constituirse en una guia para el desarrollo de actividades de analisis de datos con grandes volumenes de data, de manera que se permita conocer y aplicar los siguientes elementos: <p>
#
#  <ol>
#      <li> Importacion de librerias</li>
#      <li> Carga de Set de Datos </li>
#      <li> Integracion de los sets de datos </li>
#      <li> Trabajo con Valores Faltantes </li>
#      <li> Normalizacion de los datos </li>
#      <li> Estandarizacion de los datos </li>
#      <li> Agrupacion de los datos </li>
#      <li> Graficado de los datos </li>
#  <ol>

# %% [markdown]
# <h3 Style= 'color:#f4cf96'> 1. Importacion de librerias

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# <h3 Style= 'color:#f4cf96'> 2. Carga de Datos

# %%
cols = ["Serial_Number","List_Year", "Date_Recorded" , "Town","Address","Assessed_Value","Sale_Amount",
        "Sales_Ratio","Property_Type","Residential_Type","Non_Use_Code","Assessor_Remarks","OPM_remarks","Location"]

df_dataset = pd.read_csv("DataSet.csv", sep =";", low_memory=False)

# %%
df_dataset.shape
# Out:
# (200015, 26)

# %%
df_dataset.head(5)
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0      2020348.0     2020.0    09/13/2021  Ansonia        230 WAKELEE AVE
# 1        20002.0     2020.0       10/2/20  Ashford        390 TURNPIKE RD
# 2       200212.0     2020.0        3/9/21     Avon       5 CHESTNUT DRIVE
# 3       200243.0     2020.0    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4       200377.0     2020.0        7/2/21     Avon     70 FAR HILLS DRIVE
#
#   Assessed Value Sale Amount Sales Ratio Property Type Residential Type  ...  \
# 0      150500.00   325000.00       0.463    Commercial              NaN  ...
# 1      253000.00   430000.00      0.5883   Residential    Single Family  ...
# 2      130400.00   179900.00      0.7248   Residential            Condo  ...
# 3      619290.00   890000.00      0.6958   Residential    Single Family  ...
# 4      862330.00  1447500.00      0.5957   Residential    Single Family  ...
#
# ...

# %%
df_dataset.tail(5)
# Out:
#         Serial Number  List Year Date Recorded           Town         Address  \
# 200010        20763.0     2002.0    06/17/2003     West Haven    130 JONES ST
# 200011        21066.0     2002.0    07/22/2003  West Hartford    15 PORTER DR
# 200012        30531.0     2003.0    04/15/2004  East Hartford   43 TIFFANY RD
# 200013        30624.0     2003.0        3/3/04        Bristol   81 ANDREWS ST
# 200014        30434.0     2003.0        2/6/04      Greenwich  57 PROSPECT ST
#
#        Assessed Value Sale Amount  Sales Ratio Property Type Residential Type  \
# 200010       70700.00   179000.00  0.394972067           NaN              NaN
# 200011      240880.00   515000.00  0.467728155           NaN              NaN
# 200012       80330.00   130000.00  0.617923077           NaN              NaN
# 200013       69230.00   130000.00  0.532538462           NaN              NaN
# 200014      183470.00   375000.00  0.489253333           NaN              NaN
#
# ...

# %%
df_dataset.describe()
# Out:
#        Serial Number      List Year
# count   2.000130e+05  200013.000000
# mean    1.112790e+06    2007.822467
# std     1.272975e+07       8.656000
# min     0.000000e+00    2001.000000
# 25%     1.096800e+04    2001.000000
# 50%     2.040100e+04    2002.000000
# 75%     2.000610e+05    2020.000000
# max     2.000500e+09    2020.000000

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200015 entries, 0 to 200014
# Data columns (total 26 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     200013 non-null  float64
#  1   List Year         200013 non-null  float64
#  2   Date Recorded     200011 non-null  object
#  3   Town              200013 non-null  object
#  4   Address           200009 non-null  object
#  5   Assessed Value    200013 non-null  object
#  6   Sale Amount       200011 non-null  object
#  7   Sales Ratio       200011 non-null  object
#  8   Property Type     66804 non-null   object
#  9   Residential Type  61013 non-null   object
#  10  Non Use Code      45783 non-null   object
#  11  Assessor Remarks  14350 non-null   object
#  12  OPM remarks       2895 non-null    object
#  13  Location          57095 non-null   object
#  14  Unnamed: 14       485 non-null     object
#  15  Unnamed: 15       185 non-null     object
# ...

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 2.1 Revision de encabezados del dataFrame </h5>

# %%
df_dataset.rename({'Serial Number': 'SerialNumber'}, axis=1 , inplace=True)
df_dataset.rename({'List Year': 'ListYear'}, axis=1 , inplace=True)
df_dataset.rename({'Date Recorded': 'DateRecorded'}, axis=1 , inplace=True)
df_dataset.rename({'Assessed Value': 'AssessedValue'}, axis=1 , inplace=True)
df_dataset.rename({'Sale Amount': 'SaleAmount'}, axis=1 , inplace=True)
df_dataset.rename({'Sales Ratio': 'SalesRatio'}, axis=1 , inplace=True)
df_dataset.rename({'Property Type': 'PropertyType'}, axis=1 , inplace=True)
df_dataset.rename({'Residential Type': 'ResidentialType'}, axis=1 , inplace=True)
df_dataset.rename({'Non Use Code': 'NonUseCode'}, axis=1 , inplace=True)
df_dataset.rename({'Assessor Remarks': 'AssessorRemarks'}, axis=1 , inplace=True)
df_dataset.rename({'OPM remarks': 'OPMremarks'}, axis=1 , inplace=True)
df_dataset.columns
# Out:
# Index(['SerialNumber', 'ListYear', 'DateRecorded', 'Town', 'Address',
#        'AssessedValue', 'SaleAmount', 'SalesRatio', 'PropertyType',
#        'ResidentialType', 'NonUseCode', 'AssessorRemarks', 'OPMremarks',
#        'Location', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
df_dataset.drop(['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 
                 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1, inplace=True)

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200015 entries, 0 to 200014
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SerialNumber     200013 non-null  float64
#  1   ListYear         200013 non-null  float64
#  2   DateRecorded     200011 non-null  object
#  3   Town             200013 non-null  object
#  4   Address          200009 non-null  object
#  5   AssessedValue    200013 non-null  object
#  6   SaleAmount       200011 non-null  object
#  7   SalesRatio       200011 non-null  object
#  8   PropertyType     66804 non-null   object
#  9   ResidentialType  61013 non-null   object
#  10  NonUseCode       45783 non-null   object
#  11  AssessorRemarks  14350 non-null   object
#  12  OPMremarks       2895 non-null    object
#  13  Location         57095 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 21.4+ MB

# %%
df_dataset.head(5)
# Out:
#    SerialNumber  ListYear DateRecorded     Town                Address  \
# 0     2020348.0    2020.0   09/13/2021  Ansonia        230 WAKELEE AVE
# 1       20002.0    2020.0      10/2/20  Ashford        390 TURNPIKE RD
# 2      200212.0    2020.0       3/9/21     Avon       5 CHESTNUT DRIVE
# 3      200243.0    2020.0   04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4      200377.0    2020.0       7/2/21     Avon     70 FAR HILLS DRIVE
#
#   AssessedValue  SaleAmount SalesRatio PropertyType ResidentialType  \
# 0     150500.00   325000.00      0.463   Commercial             NaN
# 1     253000.00   430000.00     0.5883  Residential   Single Family
# 2     130400.00   179900.00     0.7248  Residential           Condo
# 3     619290.00   890000.00     0.6958  Residential   Single Family
# 4     862330.00  1447500.00     0.5957  Residential   Single Family
#
#   NonUseCode AssessorRemarks OPMremarks Location
# 0        NaN             NaN        NaN      NaN
# ...

# %% [markdown]
# <h3 Style= 'color:#f4cf96'> 4. Manejo de Datos faltantes
#
#
# <h5 Style= 'color:#e04d51'> 4.1 Identificar valores faltantes </h5>

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 4.2 Contar la cantidad de valores faltantes </h5>

# %%
dfTemp = df_dataset.isnull()
dfTemp.head(10)
# Out:
#    SerialNumber  ListYear  DateRecorded   Town  Address  AssessedValue  \
# 0         False     False         False  False    False          False
# 1         False     False         False  False    False          False
# 2         False     False         False  False    False          False
# 3         False     False         False  False    False          False
# 4         False     False         False  False    False          False
# 5         False     False         False  False    False          False
# 6         False     False         False  False    False          False
# 7         False     False         False  False    False          False
# 8         False     False         False  False    False          False
# 9         False     False         False  False    False          False
#
#    SaleAmount  SalesRatio  PropertyType  ResidentialType  NonUseCode  \
# 0       False       False         False             True        True
# ...

# %%
for column in dfTemp.columns.values.tolist():
    print(column)
    print(dfTemp[column].value_counts())
    print("")
# Out:
# SerialNumber
# False    200013
# True          2
# Name: SerialNumber, dtype: int64
#
# ListYear
# False    200013
# True          2
# Name: ListYear, dtype: int64
#
# DateRecorded
# False    200011
# True          4
# Name: DateRecorded, dtype: int64
#
# Town
# False    200013
# True          2
# Name: Town, dtype: int64
#
# Address
# False    200009
# True          6
# Name: Address, dtype: int64
#
# AssessedValue
# False    200013
# True          2
# Name: AssessedValue, dtype: int64
#
# SaleAmount
# False    200011
# True          4
# Name: SaleAmount, dtype: int64
#
# SalesRatio
# False    200011
# True          4
# Name: SalesRatio, dtype: int64
#
# PropertyType
# True     133211
# False     66804
# Name: PropertyType, dtype: int64
#
# ResidentialType
# True     139002
# False     61013
# Name: ResidentialType, dtype: int64
#
# NonUseCode
# True     154232
# False     45783
# Name: NonUseCode, dtype: int64
#
# AssessorRemarks
# True     185665
# False     14350
# ...

# %%
columnas_numericas = ['AssessedValue', 'SaleAmount','SalesRatio'] 

for col in columnas_numericas:
    df_dataset[col] = pd.to_numeric(df_dataset[col], errors='coerce')

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 4.3 Imputacion de de valores numericos </h5>

# %%
av_SerialNumber = df_dataset["SerialNumber"].astype("float").mean(axis=0)
av_ListYear = df_dataset["ListYear"].astype("float").mean(axis=0)

# %%
df_dataset["SerialNumber"].replace(np.nan, av_SerialNumber, inplace = True)
df_dataset["ListYear"].replace(np.nan, av_ListYear, inplace = True)
df_dataset.head(5)
# Out:
#    SerialNumber  ListYear DateRecorded     Town                Address  \
# 0     2020348.0    2020.0   09/13/2021  Ansonia        230 WAKELEE AVE
# 1       20002.0    2020.0      10/2/20  Ashford        390 TURNPIKE RD
# 2      200212.0    2020.0       3/9/21     Avon       5 CHESTNUT DRIVE
# 3      200243.0    2020.0   04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4      200377.0    2020.0       7/2/21     Avon     70 FAR HILLS DRIVE
#
#    AssessedValue  SaleAmount  SalesRatio PropertyType ResidentialType  \
# 0       150500.0    325000.0      0.4630   Commercial             NaN
# 1       253000.0    430000.0      0.5883  Residential   Single Family
# 2       130400.0    179900.0      0.7248  Residential           Condo
# 3       619290.0    890000.0      0.6958  Residential   Single Family
# 4       862330.0   1447500.0      0.5957  Residential   Single Family
#
#   NonUseCode AssessorRemarks OPMremarks Location
# 0        NaN             NaN        NaN      NaN
# ...

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 4.4 Imputacion de de valores categoricos </h5>

# %%
df_dataset['DateRecorded'].value_counts().idxmax()
# Out:
# '7/1/02'

# %%
df_dataset['Town'].value_counts().idxmax()
# Out:
# 'Stamford'

# %%
df_dataset['PropertyType'].value_counts().idxmax()
# Out:
# 'Residential'

# %%
df_dataset['ResidentialType'].value_counts().idxmax()
# Out:
# 'Single Family'

# %%
df_dataset["DateRecorded"].replace(np.nan, '7/1/02', inplace = True)
df_dataset["Town"].replace(np.nan, 'Stamford', inplace = True)
df_dataset["PropertyType"].replace(np.nan, 'Residential', inplace = True)
df_dataset["ResidentialType"].replace(np.nan, 'Single Family', inplace = True)
df_dataset.head(5)
# Out:
#    SerialNumber  ListYear DateRecorded     Town                Address  \
# 0     2020348.0    2020.0   09/13/2021  Ansonia        230 WAKELEE AVE
# 1       20002.0    2020.0      10/2/20  Ashford        390 TURNPIKE RD
# 2      200212.0    2020.0       3/9/21     Avon       5 CHESTNUT DRIVE
# 3      200243.0    2020.0   04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4      200377.0    2020.0       7/2/21     Avon     70 FAR HILLS DRIVE
#
#    AssessedValue  SaleAmount  SalesRatio PropertyType ResidentialType  \
# 0       150500.0    325000.0      0.4630   Commercial   Single Family
# 1       253000.0    430000.0      0.5883  Residential   Single Family
# 2       130400.0    179900.0      0.7248  Residential           Condo
# 3       619290.0    890000.0      0.6958  Residential   Single Family
# 4       862330.0   1447500.0      0.5957  Residential   Single Family
#
#   NonUseCode AssessorRemarks OPMremarks Location
# 0        NaN             NaN        NaN      NaN
# ...

# %%
df_dataset.dropna(subset = ['Address','AssessedValue','SaleAmount','SalesRatio' ], axis=0, inplace=True)
df_dataset.reset_index(drop=True, inplace=True)

# %%
dfTemp = df_dataset.isnull()
dfTemp.head(5)
for column in dfTemp.columns.values.tolist():
    print(column)
    print(dfTemp[column].value_counts())
    print("")
# Out:
# SerialNumber
# False    192592
# Name: SerialNumber, dtype: int64
#
# ListYear
# False    192592
# Name: ListYear, dtype: int64
#
# DateRecorded
# False    192592
# Name: DateRecorded, dtype: int64
#
# Town
# False    192592
# Name: Town, dtype: int64
#
# Address
# False    192592
# Name: Address, dtype: int64
#
# AssessedValue
# False    192592
# Name: AssessedValue, dtype: int64
#
# SaleAmount
# False    192592
# Name: SaleAmount, dtype: int64
#
# SalesRatio
# False    192592
# Name: SalesRatio, dtype: int64
#
# PropertyType
# False    192592
# Name: PropertyType, dtype: int64
#
# ResidentialType
# False    192592
# Name: ResidentialType, dtype: int64
#
# NonUseCode
# True     153656
# False     38936
# Name: NonUseCode, dtype: int64
#
# AssessorRemarks
# True     178698
# False     13894
# Name: AssessorRemarks, dtype: int64
#
# OPMremarks
# True     189957
# False      2635
# Name: OPMremarks, dtype: int64
#
# Location
# True     137008
# False     55584
# ...

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 4.5 Eliminar filas con valores faltantes </h5>

# %%
#df_dataset.dropna(subset = ['OPMremarks'], axis=0, inplace=True)
#df_dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# <h3 Style= 'color:#f4cf96'> 5. Estandarizacion de datos </h3>
# <h5 Style= 'color:#e04d51'> 5.1 Verificar el Dominio de las Variables</h5>

# %%
df_dataset.dtypes
# Out:
# SerialNumber       float64
# ListYear           float64
# DateRecorded        object
# Town                object
# Address             object
# AssessedValue      float64
# SaleAmount         float64
# SalesRatio         float64
# PropertyType        object
# ResidentialType     object
# NonUseCode          object
# AssessorRemarks     object
# OPMremarks          object
# Location            object
# dtype: object

# %%
df_dataset[["SerialNumber","ListYear"]] = df_dataset[["SerialNumber","ListYear"]].astype("int")
df_dataset.dtypes
# Out:
# SerialNumber         int32
# ListYear             int32
# DateRecorded        object
# Town                object
# Address             object
# AssessedValue      float64
# SaleAmount         float64
# SalesRatio         float64
# PropertyType        object
# ResidentialType     object
# NonUseCode          object
# AssessorRemarks     object
# OPMremarks          object
# Location            object
# dtype: object

# %%
df_dataset.describe()
# Out:
#        SerialNumber       ListYear  AssessedValue    SaleAmount     SalesRatio
# count  1.925920e+05  192592.000000   1.925920e+05  1.925920e+05  192592.000000
# mean   1.136508e+06    2007.978525   1.953819e+05  4.003307e+05      53.580967
# std    1.286380e+07       8.707868   7.424640e+05  1.151024e+07    5684.181567
# min    1.070000e+02    2001.000000   0.000000e+00  0.000000e+00       0.000000
# 25%    1.102675e+04    2001.000000   6.920775e+04  1.365000e+05       0.440045
# 50%    2.042300e+04    2002.000000   1.098500e+05  2.200000e+05       0.518997
# 75%    2.000770e+05    2020.000000   1.860225e+05  3.620000e+05       0.608036
# max    2.000500e+09    2020.000000   1.149242e+08  5.000000e+09  696000.000000

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 5.2 Convertir valores numericos en funcion del medio (Estandarizar) </h5>

# %%
df_dataset["AssessedValue(COLONES)"] = 545*df_dataset["AssessedValue"]
df_dataset["SaleAmount(COLONES)"] = 545*df_dataset["SaleAmount"]
df_dataset. head(4)
# Out:
#    SerialNumber  ListYear DateRecorded     Town                Address  \
# 0       2020348      2020   09/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020      10/2/20  Ashford        390 TURNPIKE RD
# 2        200212      2020       3/9/21     Avon       5 CHESTNUT DRIVE
# 3        200243      2020   04/13/2021     Avon  111 NORTHINGTON DRIVE
#
#    AssessedValue  SaleAmount  SalesRatio PropertyType ResidentialType  \
# 0       150500.0    325000.0      0.4630   Commercial   Single Family
# 1       253000.0    430000.0      0.5883  Residential   Single Family
# 2       130400.0    179900.0      0.7248  Residential           Condo
# 3       619290.0    890000.0      0.6958  Residential   Single Family
#
#   NonUseCode AssessorRemarks OPMremarks Location  AssessedValue(COLONES)  \
# 0        NaN             NaN        NaN      NaN              82022500.0
# 1        NaN             NaN        NaN      NaN             137885000.0
# ...

# %%
df_dataset.describe()
# Out:
#        SerialNumber       ListYear  AssessedValue    SaleAmount  \
# count  1.925920e+05  192592.000000   1.925920e+05  1.925920e+05
# mean   1.136508e+06    2007.978525   1.953819e+05  4.003307e+05
# std    1.286380e+07       8.707868   7.424640e+05  1.151024e+07
# min    1.070000e+02    2001.000000   0.000000e+00  0.000000e+00
# 25%    1.102675e+04    2001.000000   6.920775e+04  1.365000e+05
# 50%    2.042300e+04    2002.000000   1.098500e+05  2.200000e+05
# 75%    2.000770e+05    2020.000000   1.860225e+05  3.620000e+05
# max    2.000500e+09    2020.000000   1.149242e+08  5.000000e+09
#
#           SalesRatio  AssessedValue(COLONES)  SaleAmount(COLONES)
# count  192592.000000            1.925920e+05         1.925920e+05
# mean       53.580967            1.064831e+08         2.181803e+08
# std      5684.181567            4.046429e+08         6.273080e+09
# min         0.000000            0.000000e+00         0.000000e+00
# ...

# %%
df_dataset. head(4)
# Out:
#    SerialNumber  ListYear DateRecorded     Town                Address  \
# 0       2020348      2020   09/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020      10/2/20  Ashford        390 TURNPIKE RD
# 2        200212      2020       3/9/21     Avon       5 CHESTNUT DRIVE
# 3        200243      2020   04/13/2021     Avon  111 NORTHINGTON DRIVE
#
#    AssessedValue  SaleAmount  SalesRatio PropertyType ResidentialType  \
# 0       150500.0    325000.0      0.4630   Commercial   Single Family
# 1       253000.0    430000.0      0.5883  Residential   Single Family
# 2       130400.0    179900.0      0.7248  Residential           Condo
# 3       619290.0    890000.0      0.6958  Residential   Single Family
#
#   NonUseCode AssessorRemarks OPMremarks Location  AssessedValue(COLONES)  \
# 0        NaN             NaN        NaN      NaN              82022500.0
# 1        NaN             NaN        NaN      NaN             137885000.0
# ...

# %% [markdown]
# <h5 Style= 'color:#e04d51'> 5.3 Crear rangos para agrupar datos </h5>

# %% [markdown]
# <h2 style="color: #f4cf96">6. Visualización de Datos</h2>
# <h5 style="color: #e04d51">5.1 Configuración para los Gráficos</h5>

# %%
#Remove all axis
mpl.rcParams["axes.spines.bottom"] = True
mpl.rcParams["axes.spines.left"] = False
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False

# %% [markdown]
# <h4 style="color: #89abb4">1. ¿Cuál es el ingreso anual de las propiedades vendidas?</h4>

# %%
# Agrupar por año de lista y sumar los montos de venta para obtener el ingreso anual
annual_income = df_dataset.groupby('ListYear')['SaleAmount(COLONES)'].sum()

# Ordenar los datos por año de lista de manera descendente
annual_income = annual_income.sort_values(ascending=False)
annual_income
# Out:
# ListYear
# 2020    2.168568e+13
# 2002    9.114211e+12
# 2001    7.827952e+12
# 2003    2.970602e+12
# 2019    6.652195e+10
# 2018    5.460330e+10
# 2014    4.103102e+10
# 2013    3.706665e+10
# 2017    3.680308e+10
# 2006    3.471932e+10
# 2010    2.426586e+10
# 2015    2.096542e+10
# 2012    2.086587e+10
# 2007    1.802829e+10
# 2016    1.597864e+10
# 2009    1.533683e+10
# 2011    1.410185e+10
# 2005    1.229694e+10
# 2008    8.537773e+09
# 2004    2.076450e+08
# Name: SaleAmount(COLONES), dtype: float64

# %%
from matplotlib.ticker import FormatStrFormatter
fig, ax = plt.subplots(figsize=(15, 6.9), dpi=100)

eje_x = annual_income.index.tolist()
data = annual_income.values
bar_colors = ['#ac4d5e']
ax.bar(eje_x, data, color=bar_colors)

#--------------------------------------------------------------------------------------------------------------------#
#--------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EJES DEL GRAFICO ------------------------------------#
#--------------------------------------------------------------------------------------------------------------------#
#FORMATO DEL TITULO
title = "Grafico 1: Ingreso Anual de propiedades vendidas"
plt.suptitle(title,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.87,
             transform = fig.transFigure,
             fontsize = 20,
             fontweight = "bold",
             fontfamily = "serif")

 

#FORMATO DEL SUBTITULO
subTitle = "Ingreso Anual (colones)"  
ax.set_title(subTitle,
             horizontalalignment = 'left',
             x = 0.001,
             y = 0.80,
             transform = fig.transFigure,
             fontsize = 15,
             fontweight = "regular",
             fontfamily = "serif")

 

#FORMATO DE LOS EJES
etiqueta = "Año de lista"
ax.set_xlabel(etiqueta,
              ha = 'left',
              fontsize = 10,
              fontweight = "regular",
              fontfamily = "serif")

 

#CONFIGURACION DE COORDENADAS DE LA ETIQUETA DEL EJE X
ax.xaxis.set_label_coords(x=0,
                          y=-0.07,
                          transform=ax.transAxes)

 

#CONFIGURACION EL TAMANO DEL TEXTO DEL EJE Y
ax.tick_params(axis='both',
               labelsize=10)

# Ajustar el formato de los valores en el eje y a dos decimales
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

# Ajustar el formato de los valores en el eje x a números enteros
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True)) 

#CONFIGURACION LA UBICACION DEL GRAFICO
plt.subplots_adjust(top=0.80)
plt.show()

# %% [markdown]
# <h4 style="color: #89abb4">2. ¿Qué tipo de propiedad tiene mayor facilidad de venta?</h4>

# %%
def is_alphanumeric(value):
    return str(value).isalpha()

# Filtrar y reemplazar valores numéricos en la columna "PropertyType"
df_dataset['PropertyType'] = df_dataset['PropertyType'].apply(lambda x: x if is_alphanumeric(x) else None)

# %%
filtered_df = df_dataset[df_dataset['PropertyType'] != 'SerialNumber']

# Agrupar por tipo de propiedad y contar la cantidad de ventas para cada tipo
property_counts = filtered_df['PropertyType'].value_counts()
property_counts
# Out:
# Residential    186629
# Commercial       1866
# Apartments        462
# Condo             365
# Industrial        218
# Name: PropertyType, dtype: int64

# %%
import matplotlib.pyplot as plt

# Filtrar los valores numéricos en la columna 'PropertyType'
filtered_df = df_dataset[df_dataset['PropertyType'] != 'SerialNumber']

# Agrupar por tipo de propiedad y contar la cantidad de ventas para cada tipo
property_counts = filtered_df['PropertyType'].value_counts()

# Crear la figura y el eje
fig, ax = plt.subplots(figsize=(15, 6.9), dpi=100)

# Generar el gráfico de barras horizontales
eje_x = property_counts.index.tolist()
data = property_counts.values
bar_colors = ['#375779']
ax.bar(eje_x, data, color=bar_colors)

# Configuración de títulos, etiquetas y formato de ejes
title = "Grafico 2: Facilidad de Venta por Tipo de Propiedad"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=20,
             fontweight="bold",
             fontfamily="serif")

subTitle = "Cantidad de Ventas agrupadas por Tipo de Propiedad"
ax.set_title(subTitle,
             horizontalalignment='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=15,
             fontweight="regular",
             fontfamily="serif")

etiqueta = "Cantidad de Ventas"
ax.set_xlabel(etiqueta,
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")

# Ajustar el formato de los valores en el eje x a números enteros
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Configuración de la ubicación del gráfico
plt.subplots_adjust(top=0.65)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #89abb4">3. ¿En cuál ciudad o pueblo se dan mayor cantidad de ventas de
# propiedades? Y ¿Qué elementos particulares tienen esas ciudades o
# pueblos?:</h4>

# %%
# Filtrar el DataFrame para excluir la fila correspondiente a "Serial Number"
filtered_df = df_dataset[df_dataset['PropertyType'] != 'SerialNumber']

# Agrupar por ciudad o pueblo y contar la cantidad de ventas para cada uno
town_counts = filtered_df['Town'].value_counts()

# Tomar las 10 ciudades o pueblos con mayor cantidad de ventas
top_towns = town_counts.head(10)
top_towns
# Out:
# Stamford         7612
# Norwalk          5753
# Bridgeport       5506
# Danbury          4564
# Hartford         4189
# Milford          4172
# Stratford        4036
# West Hartford    3926
# Greenwich        3825
# Bristol          3713
# Name: Town, dtype: int64

# %%
# Crear la figura y el eje
fig, ax = plt.subplots(figsize=(8, 8), dpi=100)

# Generar el gráfico circular (pastel)
wedges, texts, autotexts = ax.pie(top_towns, labels=top_towns.index,
                                   autopct='%1.1f%%', startangle=140, colors=['#e5b1d0', '#e2c3a5', '#125b52', 
                                                                              '#518f42', '#71d6d6', '#2bcac8',
                                                                              '#268eb1', '#8c4363', '#ceb94b', '#ffac96'])

#--------------------------------------------------------------------------------------------------------------------#
#--------------------CONFIGURACION DE LOS TITULOS, SUBTITULOS Y EJES DEL GRAFICO ------------------------------------#
#--------------------------------------------------------------------------------------------------------------------#
# Ajustar formato de etiquetas y porcentaje en el gráfico
for autotext in autotexts:
    autotext.set_fontsize(10)
    autotext.set_color('white')

# Configuración de título
title = "Grafico 3. Porcentaje de ventas por ciudad"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=16,
             fontweight="bold",
             fontfamily="serif",)

# Configuración de subtítulo
subTitle = "Cantidad de ventas de propiedades agrupadas por Ciudad o Pueblo"
ax.set_title(subTitle,
             horizontalalignment='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=11,
             fontweight="regular",
             fontfamily="serif")

# Ajustar la ubicación del gráfico
plt.subplots_adjust(top=0.65)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #89abb4">4.¿Cuál es el costo promedio de las propiedades residenciales y
# comerciales?:</h4>

# %%
# Filtrar el DataFrame para incluir solo propiedades residenciales y comerciales
filtered_df = df_dataset[(df_dataset['PropertyType'] == 'Residential') |
                         (df_dataset['PropertyType'] == 'Commercial')]

# Agrupar por tipo de propiedad y calcular el costo promedio
average_cost_by_property = filtered_df.groupby('PropertyType')['SaleAmount(COLONES)'].mean()
average_cost_by_property
# Out:
# PropertyType
# Commercial     9.972809e+08
# Residential    1.930446e+08
# Name: SaleAmount(COLONES), dtype: float64

# %%
# Crear la figura y el eje
fig, ax = plt.subplots(figsize=(8, 6), dpi=100)

# Generar el gráfico de barras
eje_x = average_cost_by_property.index.tolist()
data = average_cost_by_property.values
bar_colors = ['#7e6f87']
bars = ax.bar(eje_x, data, color=bar_colors)

# Configuración de títulos y etiquetas
title = "Grafico 4. Costo Promedio de Propiedades Residenciales y Comerciales"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=16,
             fontweight="bold",
             fontfamily="serif")

subTitle = "Promedio de Costo por Tipo de Propiedad"
ax.set_title(subTitle,
             horizontalalignment='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=11,
             fontweight="regular",
             fontfamily="serif")

etiqueta = "Costo Promedio (Colones)"
ax.set_ylabel(etiqueta,
              ha='right',
              fontsize=8,
              fontweight="regular",
              fontfamily="serif")

ax.xaxis.set_label_coords(x=0,
                          y=-0.07,
                          transform=ax.transAxes)

ax.tick_params(axis='both',
               labelsize=10)

plt.subplots_adjust(top=0.65)

# Ajustar el formato de los valores en el eje y a números enteros
ax.yaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #89abb4">5.¿Cuál es el tipo de propiedades residenciales que se vende con mayor frecuencia, dónde y con qué costo promedio?:</h4>

# %%
# Filtrar el DataFrame para incluir solo propiedades residenciales
residential_df = df_dataset[df_dataset['PropertyType'] == 'Residential']

# Obtener el tipo de propiedades residenciales más común
most_common_residential_type = residential_df['ResidentialType'].value_counts().idxmax()

# Filtrar el DataFrame para incluir solo el tipo de propiedad residencial más común
most_common_residential_df = residential_df[residential_df['ResidentialType'] == most_common_residential_type]
most_common_residential_type
# Out:
# 'Single Family'

# %%
# Agrupar por ciudad o pueblo y calcular la cantidad de ventas y el costo promedio
city_sales_info = most_common_residential_df.groupby('Town').agg({'SaleAmount(COLONES)': 'count', 'SaleAmount(COLONES)': 'mean'})
city_sales_info
# Out:
#                SaleAmount(COLONES)
# Town
# Andover               1.262511e+08
# Ansonia               1.110217e+08
# Ashford               9.407703e+07
# Avon                  2.324313e+08
# Barkhamsted           1.102326e+08
# ...                            ...
# Windsor Locks         9.813460e+07
# Wolcott               1.318162e+08
# Woodbridge            2.368754e+08
# Woodbury              1.796162e+08
# Woodstock             1.113685e+08
#
# [169 rows x 1 columns]

# %%
# Crear la figura y el eje para el gráfico
fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

# Ordenar los datos en orden descendente y seleccionar las top 10 ciudades
city_sales_info_sorted = city_sales_info.sort_values('SaleAmount(COLONES)', ascending=False)
top_n = 10
top_cities = city_sales_info_sorted.index[:top_n]
data = city_sales_info_sorted.loc[top_cities, 'SaleAmount(COLONES)'].values

# Generar el gráfico de barras para la cantidad de ventas por ciudad o pueblo
bar_colors = ['#c2c199']
ax.barh(top_cities, data, color=bar_colors)
title = "Grafico 5. Ventas de Propiedades Single Family por Ciudad o Pueblo"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=14,
             fontweight="bold",
             fontfamily="serif")

subTitle = "Top 10 ciudades con más ventas"
ax.set_title(subTitle,
             horizontalalignment='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=12,
             fontweight="regular",
             fontfamily="serif")

ax.set_xlabel("Cantidad de Ventas",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")
ax.set_ylabel("Ciudad o Pueblo",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")
ax.xaxis.set_label_coords(x=0,
                          y=-0.07,
                          transform=ax.transAxes)
ax.tick_params(axis='both', labelsize=10)
plt.subplots_adjust(top=0.80)

# Mostrar el gráfico
plt.show()

# %%
# Seleccionar las 10 ciudades con más ventas
top_cities = city_sales_info.nlargest(10, 'SaleAmount(COLONES)').index.tolist()
top_data = city_sales_info.nlargest(10, 'SaleAmount(COLONES)')['SaleAmount(COLONES)'].values

# Crear la figura y el eje para el segundo gráfico
fig, ax2 = plt.subplots(figsize=(10, 6), dpi=100)

# Generar el gráfico de dispersión para el costo promedio por ciudad o pueblo
ax2.scatter(top_cities, top_data, color='#cc5025')

# Configuración de los títulos y ejes
title = "Grafico 5.1: Propiedades"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=16,
             fontweight="bold",
             fontfamily="serif")

subTitle = "Costo Promedio de Propiedades por Ciudad o Pueblo (Top 10)"
ax2.set_title(subTitle,
              horizontalalignment='left',
              x=0.001,
              y=0.80,
              transform=fig.transFigure,
              fontsize=11,
              fontweight="regular",
              fontfamily="serif")

etiqueta = "Ciudad o Pueblo"
ax2.set_xlabel(etiqueta,
               ha='left',
               fontsize=10,
               fontweight="regular",
               fontfamily="serif")

etiquetay = "Costo Promedio (colones)"
ax2.set_ylabel(etiquetay,
               ha='left',
               fontsize=10,
               fontweight="regular",
               fontfamily="serif")

ax2.xaxis.set_label_coords(x=0,
                           y=-0.07,
                           transform=ax2.transAxes)

ax2.yaxis.set_label_coords(x=-0.15,
                           y=0.45,
                           transform=ax2.transAxes)

ax2.tick_params(axis='both',
                labelsize=10)
ax2.yaxis.set_major_formatter('₡{x:,.0f}')  # Formatear el eje y como moneda

# Mostrar el segundo gráfico
plt.subplots_adjust(top=0.70)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h4 style="color: #89abb4">6. ¿Cuál es margen promedio de ganancia por cada una de las
# propiedades vendidas?:</h4>

# %%
# Filtrar y agrupar los datos
property_type_groups = df_dataset.groupby('PropertyType')

# Calcular el margen promedio de ganancia por cada tipo de propiedad
margins = property_type_groups.apply(lambda x: (x['SaleAmount'] - x['AssessedValue']).mean())
margins_sorted = margins.sort_values(ascending=False)
margins
# Out:
# PropertyType
# Apartments     1.215210e+07
# Commercial     5.274421e+05
# Condo          7.954410e+04
# Industrial     7.438227e+05
# Residential    1.720407e+05
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10, 6))
margins_sorted.plot(kind='barh', color='#125b52', ax=ax)  # Usar kind='barh' para barras horizontales

# Configurar el formato del gráfico
title = "Grafico 6. Promedio de ganancias de las propiedades vendidas"
plt.suptitle(title,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=14,
             fontweight="bold",
             fontfamily="serif")

subTitle = "Margen promedio de ganancia"
ax.set_title(subTitle,
             horizontalalignment='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=12,
             fontweight="regular",
             fontfamily="serif")

ax.set_xlabel("Margen Promedio", fontsize=12, fontweight="regular", fontfamily="serif")
ax.set_ylabel("Tipo de Propiedad", fontsize=12, fontweight="regular", fontfamily="serif")

ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
plt.subplots_adjust(top=0.70)

# Mostrar el gráfico
plt.tight_layout()
plt.show()
